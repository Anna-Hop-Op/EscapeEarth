# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Hop-Op/EscapeEarth/blob/main/interns-AnnaClaire/Activity2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mpl

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
my_path = '/content/gdrive/My Drive/EscapeEarthData/Activity-2/'

df1 = pd.read_csv('{}df1.csv'.format(my_path))
df2 = pd.read_csv('{}df2.csv'.format(my_path))
df3 = pd.read_csv('{}df3.csv'.format(my_path))
df4 = pd.read_csv('{}df4.csv'.format(my_path))
df5 = pd.read_csv('{}df5.csv'.format(my_path))
df6 = pd.read_csv('{}df6.csv'.format(my_path))
df7 = pd.read_csv('{}df7.csv'.format(my_path))
df8 = pd.read_csv('{}df8.csv'.format(my_path))

# %%
plt.scatter(df1['col1'], df1['col2'], s = 0.5, color = "wheat")

# %%
plt.scatter(df2['col1'], df2['col2'], s = 0.5, color = "powderblue")

# %%
plt.scatter(df3['col1'], df3['col2'], s = 0.5, color = "lightpink")

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df1['col1'].to_numpy()], [df1['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df1_new_col1 = c_new[0].l.degree
        df1_new_col2 = c_new[0].b.degree
new_data = {'col1':df1_new_col1,'col2':df1_new_col2}
df1_new = pd.DataFrame(new_data)

# %%
df1_new
# Out:
#              col1       col2
# 0       73.212025  26.083740
# 1       73.301850  26.150703
# 2       73.303373  26.149660
# 3       74.725503  26.406158
# 4       74.601528  26.272399
# ...           ...        ...
# 19995   94.296868  14.060950
# 19996   96.958933  16.466131
# 19997   96.958430  16.465971
# 19998   98.794766  17.823635
# 19999  103.102339  19.877730
#
# [20000 rows x 2 columns]

# %%
plt.scatter(df1_new['col1'], df1_new['col2'], s = 0.5, color = "lightgreen")
